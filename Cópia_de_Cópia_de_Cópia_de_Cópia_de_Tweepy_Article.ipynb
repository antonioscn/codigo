# %% [markdown]
# <a href="https://colab.research.google.com/github/dataneto/codigo/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_C%C3%B3pia_de_C%C3%B3pia_de_Tweepy_Article.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import pandas as pd
from tabulate import tabulate

# %%
# authenticating twitter api credentials
consumer_key = 'ChApBSNK4VDdZvMzekh1C797y'
consumer_secret = 'HGNpMBexSbS9seKPYYfh8BeqLPy4FSl4p7kNj6e8N7LAtWB17Q'
access_token = '1000032762064199680-GYlAlHFWWlm7b6ATIW69HgeYrZjwWR'
access_token_secret = 'nFBeaM6RT1hKpVqTl4hnv1X1TLWveiaO8RN4nUybEwV5r'

# instantiate the api
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
user = api.get_user("isro")
print("User Details:")
print(tabulate([["Name","Description","Location"],[user.name,user.description,user.location]],headers="firstrow"))
# Out:
# User Details:
# Name    Description                         Location
# ------  ----------------------------------  ----------
# ISRO    Indian Space Research Organisation  Bangalore

# %%
users = pd.read_csv('https://raw.githubusercontent.com/dataneto/AnalisandoAPandemia/main/Usuarios/Ativos/Usuarios_verificados/users?token=AP2O2Y5XMVZ7ZXL5SYA5LNDACG5GK')
users
# Out:
#         Unnamed: 0  Unnamed: 0.1              user_id         username
# 0                0             1            138528069       letrapreta
# 1                1             2             15336738        bicmuller
# 2                2             3             14128609       felipeneto
# 3                3             4             13769472           oatila
# 4                4             5             93619760  eldacarvalhobsb
# ...            ...           ...                  ...              ...
# 112050      112050        112051           2211572112          bakktot
# 112051      112051        112052   807274241229996032  miguelramosdos1
# 112052      112052        112053  1242922066728361987  cristia62775796
# 112053      112053        112054           2384399599         said_290
# 112054      112054        112055  1241018077745221635   portalopoder__
#
# [112055 rows x 4 columns]

# %%
users1 = users[:10000]
users2 = users[10000:20000]
users3 = users[20000:30000]
users4 = users[30000:40000]
users5 = users[40000:50000]
users6 = users[50000:60000]
users7 = users[60000:70000]
users8 = users[70000:80000]
users9 = users[80000:90000]
users10 = users[90000:100000]
users11 = users[100000:110000]
users12 = users[110000:]

users1
# Out:
#       Unnamed: 0  Unnamed: 0.1              user_id         username
# 0              0             1            138528069       letrapreta
# 1              1             2             15336738        bicmuller
# 2              2             3             14128609       felipeneto
# 3              3             4             13769472           oatila
# 4              4             5             93619760  eldacarvalhobsb
# ...          ...           ...                  ...              ...
# 9995        9995          9996   981197672823574528   livia_schueler
# 9996        9996          9997  1168574300372291584   placidowaleria
# 9997        9997          9998  1243632710402351110  alexandreperso5
# 9998        9998          9999            172590184        csmelissa
# 9999        9999         10000  1258240926448848896   carlagaldino35
#
# [10000 rows x 4 columns]

# %%
users1.to_csv('users1')
users2.to_csv('users2')
users3.to_csv('users3')
users4.to_csv('users4')
users5.to_csv('users5')
users6.to_csv('users6')
users7.to_csv('users7')
users8.to_csv('users8')
users9.to_csv('users9')
users10.to_csv('users10')
users11.to_csv('users11')
users12.to_csv('users12')

# %% [markdown]
# ## users4:

# %%
u = pd.read_csv('/content/users6')

# %%
u
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 0          50000         50000  ...  1125810533851115521  vendruscololuiz
# 1          50001         50001  ...  1237695287638069250  anaclud03657519
# 2          50002         50002  ...             55849356       clecyrampi
# 3          50003         50003  ...           2880368050         gamito42
# 4          50004         50004  ...            301673500       jaimegroff
# ...          ...           ...  ...                  ...              ...
# 9995       59995         59995  ...  1253732338284068873      viriatomila
# 9996       59996         59996  ...  1272928056286511105      l3340019157
# 9997       59997         59997  ...  1113792355931435009     adilsonagura
# 9998       59998         59998  ...  1275261776310001669       silviocar1
# 9999       59999         59999  ...           1473207200     rcardoso1956
#
# [10000 rows x 5 columns]

# %%
u1 =u[:500]
u2 = u[500:1000]
u3 = u[1000:1500]
u4 = u[1500:2000]
u5 = u[2000:2500]
u6 = u[2500:3000]
u7 = u[3000:3500]
u8 = u[3500:4000]
u9 = u[4000:4500]
u10 = u[4500:5000]
u11 = u[5000:5500]
u12 = u[5500:6000]
u13 = u[6000:6500]
u14 = u[6500:7000]
u15 = u[7000:7500]
u16 = u[7500:8000]
u17 = u[8000:8500]
u18 = u[8500:9000]
u19 = u[9000:9500]
u20 = u[9500:]

# %%
data = []   #para criar o df com as respostas

for x in u16.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    nome = user.name #Selecionando o nome
    descricao = user.description #selecionando a descição
    localizacao = user.location #selecionando a localização
    data.append((usuario, nome, descricao, localizacao))

  except: #Ignorando erros
      pass

cols=['usuario', 'nome', 'descricao', 'localizacao'] #Criando o df com as respostas
usuarios1_16 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_16
# Out:
#              usuario  ...                localizacao
# 0    pierry_fernanda  ...
# 1     Gabriel_anonim  ...
# 2     LucioPinheiro5  ...  A dois passos do paraíso
# 3         Chelkanoff  ...           Porto Alegre, RS
# 4           mateusmy  ...
# ..               ...  ...                        ...
# 382  MateusO29794341  ...           Curitiba, Brasil
# 383    omarcosaraujo  ...            Salvador, Bahia
# 384        hole_year  ...             hole year#0680
# 385        Lili13tan  ...
# 386     RMal00030497  ...       Porto Alegre, Brasil
#
# [387 rows x 4 columns]

# %%
u16
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 7500       57500         57500  ...   905848783262638080  pierry_fernanda
# 7501       57501         57501  ...  1237697245765648384   gabriel_anonim
# 7502       57502         57502  ...   951259447992692736   luciopinheiro5
# 7503       57503         57503  ...             77765453       chelkanoff
# 7504       57504         57504  ...             28327684         mateusmy
# ...          ...           ...  ...                  ...              ...
# 7995       57995         57995  ...             26669635    omarcosaraujo
# 7996       57996         57996  ...           1694093630        hole_year
# 7997       57997         57997  ...   730190608363601920       vitandre99
# 7998       57998         57998  ...  1171573668683685898        lili13tan
# 7999       57999         57999  ...   971149595312115712     rmal00030497
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u17.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    nome = user.name #Selecionando o nome
    descricao = user.description #selecionando a descição
    localizacao = user.location #selecionando a localização
    data.append((usuario, nome, descricao, localizacao))

  except: #Ignorando erros
      pass

cols=['usuario', 'nome', 'descricao', 'localizacao'] #Criando o df com as respostas
usuarios1_17 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_17
# Out:
#              usuario  ...             localizacao
# 0           DPenha01  ...
# 1      hufflepuffboy  ...
# 2       claudio19842  ...
# 3          tulliomtt  ...          Palmas, Brasil
# 4        HomemPegada  ...       São Paulo, Brasil
# ..               ...  ...                     ...
# 389     Pabloquadros  ...  Brasil, Rio de Janeiro
# 390     alves_silva2  ...         Aracaju, Brasil
# 391  Ricardo73754295  ...
# 392   DanielBrasilia  ...        Brasília, Brazil
# 393       lplacencia  ...       Santiago de Chile
#
# [394 rows x 4 columns]

# %%
u17
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 8000       58000         58000  ...  1241021257803497472         dpenha01
# 8001       58001         58001  ...  1240775973395673089       avelar1305
# 8002       58002         58002  ...             32479303       xandyalves
# 8003       58003         58003  ...  1205797055186292737    hufflepuffboy
# 8004       58004         58004  ...  1256203229546844160     claudio19842
# ...          ...           ...  ...                  ...              ...
# 8495       58495         58495  ...             81232818     pabloquadros
# 8496       58496         58496  ...            387304069     alves_silva2
# 8497       58497         58497  ...  1131338424210866176  ricardo73754295
# 8498       58498         58498  ...             36886145   danielbrasilia
# 8499       58499         58499  ...            176541936       lplacencia
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u18.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    nome = user.name #Selecionando o nome
    descricao = user.description #selecionando a descição
    localizacao = user.location #selecionando a localização
    data.append((usuario, nome, descricao, localizacao))

  except: #Ignorando erros
      pass

cols=['usuario', 'nome', 'descricao', 'localizacao'] #Criando o df com as respostas
usuarios1_18 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_18
# Out:
#              usuario  ...        localizacao
# 0          rafaelsrs  ...     Rio de Janeiro
# 1        salltorelli  ...   São Paulo-Brasil
# 2      Maisa95955569  ...  São Paulo, Brasil
# 3        GracieleVaz  ...   Brasília, Brasil
# 4     geraldosales02  ...  Guarulhos, Brasil
# ..               ...  ...                ...
# 388  Ricardo15794400  ...   Salvador, Brasil
# 389     daoraalisson  ...   Salvador, Brasil
# 390     paulavrocham  ...     Recife, Brasil
# 391  RodrigoCartafi1  ...
# 392          izahice  ...
#
# [393 rows x 4 columns]

# %%
u18
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 8500       58500         58500  ...             52593944        rafaelsrs
# 8501       58501         58501  ...             16241197      salltorelli
# 8502       58502         58502  ...  1229416035368996868    maisa95955569
# 8503       58503         58503  ...            404995582      gracielevaz
# 8504       58504         58504  ...           4833133642   geraldosales02
# ...          ...           ...  ...                  ...              ...
# 8995       58995         58995  ...   999835529704243205     paulavrocham
# 8996       58996         58996  ...  1181214449551761408  rodrigocartafi1
# 8997       58997         58997  ...           4652977637      enzoshelby_
# 8998       58998         58998  ...  1280441396307144704    livia82027207
# 8999       58999         58999  ...           3628194021          izahice
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u19.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    nome = user.name #Selecionando o nome
    descricao = user.description #selecionando a descição
    localizacao = user.location #selecionando a localização
    data.append((usuario, nome, descricao, localizacao))

  except: #Ignorando erros
      pass

cols=['usuario', 'nome', 'descricao', 'localizacao'] #Criando o df com as respostas
usuarios1_19 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_19
# Out:
#              usuario  ...           localizacao
# 0        annette_Gja  ...    Guarujá, São Paulo
# 1      diego_lamarck  ...  Porto Alegre, Brasil
# 2    MarianaCristian  ...           Dubai - UAE
# 3       CrisssBonfim  ...                Brasil
# 4         gsandrade_  ...             Santos SP
# ..               ...  ...                   ...
# 379    tiadowhatsapp  ...
# 380         ana_noh_  ...         Goiás, Brasil
# 381       MenesLeite  ...
# 382     falamatheusa  ...            Fortalcity
# 383  Jaqueli41883643  ...
#
# [384 rows x 4 columns]

# %%
u19
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 9000       59000         59000  ...  1263862181931687936      roseiralmiu
# 9001       59001         59001  ...           1663709322         uriexlwt
# 9002       59002         59002  ...             69738992      annette_gja
# 9003       59003         59003  ...  1278121884572422144    diego_lamarck
# 9004       59004         59004  ...            175048113  marianacristian
# ...          ...           ...  ...                  ...              ...
# 9495       59495         59495  ...  1059225042473639937    tiadowhatsapp
# 9496       59496         59496  ...           2956948708         ana_noh_
# 9497       59497         59497  ...  1219944427839459333       menesleite
# 9498       59498         59498  ...   937079948581449731     falamatheusa
# 9499       59499         59499  ...   967559213990989825  jaqueli41883643
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u20.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    nome = user.name #Selecionando o nome
    descricao = user.description #selecionando a descição
    localizacao = user.location #selecionando a localização
    data.append((usuario, nome, descricao, localizacao))

  except: #Ignorando erros
      pass

cols=['usuario', 'nome', 'descricao', 'localizacao'] #Criando o df com as respostas
usuarios1_20 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_20
# Out:
#              usuario  ...                  localizacao
# 0          tinasfuck  ...           São Paulo, Brasil
# 1         innercidio  ...                        ישראל
# 2        vitorstein_  ...
# 3    AntonioJoarlis1  ...
# 4          FatPanzon  ...              Alagoas, Brasil
# ..               ...  ...                          ...
# 388          BiFator  ...
# 389        brunodesi  ...       Belo Horizonte, Brasil
# 390      ViriatoMila  ...
# 391     AdilsonAgura  ...                       Santos
# 392     rcardoso1956  ...  Portugal e Brasil - Floripa
#
# [393 rows x 4 columns]

# %%
u20
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 9500       59500         59500  ...            341907471       fecripardo
# 9501       59501         59501  ...  1064288846966374400        tinasfuck
# 9502       59502         59502  ...  1143614759109046273       innercidio
# 9503       59503         59503  ...            137532089      vitorstein_
# 9504       59504         59504  ...  1278835263851110407  antoniojoarlis1
# ...          ...           ...  ...                  ...              ...
# 9995       59995         59995  ...  1253732338284068873      viriatomila
# 9996       59996         59996  ...  1272928056286511105      l3340019157
# 9997       59997         59997  ...  1113792355931435009     adilsonagura
# 9998       59998         59998  ...  1275261776310001669       silviocar1
# 9999       59999         59999  ...           1473207200     rcardoso1956
#
# [500 rows x 5 columns]

# %%
metade1_ = [usuarios1_16, usuarios1_17, usuarios1_18, usuarios1_19, usuarios1_20]

# %%
metade6_4 = pd.concat(metade1_)

# %%
metade5_4
# Out:
#              usuario  ...        localizacao
# 0        mandanarhan  ...      Paris, France
# 1             alien9  ...          São Paulo
# 2         Buy_TheDip  ...
# 3       Borba_Mello2  ...  São Paulo, Brasil
# 4    filho_terciofut  ...   Fortaleza, Ceará
# ..               ...  ...                ...
# 389        fuckitray  ...      Goiás, Brasil
# 390      elisaaraujo  ...             Brasil
# 391   RobertoPaixo11  ...  São Paulo, Brasil
# 392         OChacal5  ...
# 393        HPaglacci  ...
#
# [1953 rows x 4 columns]

# %%
metade6_4.to_csv('metade6_4')

# %% [markdown]
# apartir do 10

# %%
data = []   #para criar o df com as respostas

for x in u10.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_10 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_10 #Mostrabdo o df com as respostas
# Out:
#              usuario
# 0     matheusbbgodoy
# 1     Anamfranceschi
# 2          blangeani
# 3     pibervaldecir1
# 4       mikka_sansil
# ..               ...
# 367     PrudencianaF
# 368  Eduardo47890320
# 369      a_mergulhao
# 370   capitaldigital
# 371   GuedeFigueredo
#
# [372 rows x 1 columns]

# %%
u10
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 4500       34500         34500  ...   826865399547494400   matheusbbgodoy
# 4501       34501         34501  ...  1114576117439062025   anamfranceschi
# 4502       34502         34502  ...  1253711644540252161   ferreiraogilio
# 4503       34503         34503  ...             90425731        blangeani
# 4504       34504         34504  ...   741391818651226112   pibervaldecir1
# ...          ...           ...  ...                  ...              ...
# 4995       34995         34995  ...  1152446487433043968  eduardo47890320
# 4996       34996         34996  ...  1072310714562424834       vitorkkkjj
# 4997       34997         34997  ...            277513248      a_mergulhao
# 4998       34998         34998  ...             17066059   capitaldigital
# 4999       34999         34999  ...           1161279913   guedefigueredo
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u11.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_11 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_11
# Out:
#             usuario
# 0       jengofrengs
# 1      thisnotatest
# 2       ElaineM2Ana
# 3    marcelo_mazuco
# 4     tipssovetorax
# ..              ...
# 388     Gui2barbosa
# 389         josisln
# 390     LuisOtavioV
# 391    essefabricio
# 392    migoseutonto
#
# [393 rows x 1 columns]

# %%
u11
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 5000       35000         35000  ...  1248362746288254978     silvioforato
# 5001       35001         35001  ...  1078297819746832384  cacadordeminion
# 5002       35002         35002  ...           1555778688      jengofrengs
# 5003       35003         35003  ...            222777990     thisnotatest
# 5004       35004         35004  ...            712296098      elainem2ana
# ...          ...           ...  ...                  ...              ...
# 5495       35495         35495  ...           3539733255      gui2barbosa
# 5496       35496         35496  ...            380034758          josisln
# 5497       35497         35497  ...            255696404      luisotaviov
# 5498       35498         35498  ...   882694254321164289     essefabricio
# 5499       35499         35499  ...             75175340     migoseutonto
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u12.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_12 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_12
# Out:
#              usuario
# 0          SOL_MORAS
# 1        Oliveirxyas
# 2             CibsKz
# 3             zkadin
# 4        BrunoSanAnd
# ..               ...
# 393    renatarafaeju
# 394      EngMosquera
# 395     KayoJustosII
# 396  MarinaR84233514
# 397  mariabe22360758
#
# [398 rows x 1 columns]

# %%
u12
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 5500       35500         35500  ...             31910863        sol_moras
# 5501       35501         35501  ...  1190034447229505536      oliveirxyas
# 5502       35502         35502  ...   896012455591149569           cibskz
# 5503       35503         35503  ...            136798258           zkadin
# 5504       35504         35504  ...  1241867182872629250      brunosanand
# ...          ...           ...  ...                  ...              ...
# 5995       35995         35995  ...            243945810      engmosquera
# 5996       35996         35996  ...  1022825135546556417       duarttvall
# 5997       35997         35997  ...  1215346517617315841     kayojustosii
# 5998       35998         35998  ...  1128320616803786752  marinar84233514
# 5999       35999         35999  ...   985949817577902081  mariabe22360758
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u13.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_13 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_13
# Out:
#              usuario
# 0         Mabrandao4
# 1         PedrosaLeo
# 2        pepitoevsky
# 3      RichardKloppe
# 4             rxcnha
# ..               ...
# 412   RheynerFreitas
# 413           uarlem
# 414       cumpanhero
# 415  ClaudinhoMorei4
# 416          cjfaria
#
# [417 rows x 1 columns]

# %%
u13
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 6000       36000         36000  ...  1142593559159365632       mabrandao4
# 6001       36001         36001  ...            123627303       pedrosaleo
# 6002       36002         36002  ...            247018076      pepitoevsky
# 6003       36003         36003  ...            375081680    richardkloppe
# 6004       36004         36004  ...           1716683257           rxcnha
# ...          ...           ...  ...                  ...              ...
# 6495       36495         36495  ...  1184251389771419648       cumpanhero
# 6496       36496         36496  ...  1171017697607462912  claudinhomorei4
# 6497       36497         36497  ...             52477295          cjfaria
# 6498       36498         36498  ...            471522599   werber_antonyo
# 6499       36499         36499  ...  1231674384496185345   bobcat35746791
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u14.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_14 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_14
# Out:
#             usuario
# 0     ornieskipedro
# 1    PauloFidelis10
# 2     liliam_melo02
# 3    IreneCorreia12
# 4      Brunorafa182
# ..              ...
# 385    joaovitorm01
# 386   Silvarobert20
# 387      perplexa26
# 388  SoniaMZanetti1
# 389          lbkuhn
#
# [390 rows x 1 columns]

# %%
u14
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id        username
# 6500       36500         36500  ...  1016521304500047873   ornieskipedro
# 6501       36501         36501  ...  1084087233991319554  paulofidelis10
# 6502       36502         36502  ...             77660315   liliam_melo02
# 6503       36503         36503  ...  1156004828453036038  irenecorreia12
# 6504       36504         36504  ...             49745830    brunorafa182
# ...          ...           ...  ...                  ...             ...
# 6995       36995         36995  ...           3083256794    joaovitorm01
# 6996       36996         36996  ...  1252358992514502656   silvarobert20
# 6997       36997         36997  ...           4137127533      perplexa26
# 6998       36998         36998  ...  1045469496624992257  soniamzanetti1
# 6999       36999         36999  ...           2235839522          lbkuhn
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u15.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_15 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_15
# Out:
#              usuario
# 0        esquerdovky
# 1          magaligna
# 2    _rodrigocosta37
# 3         EduardoVet
# 4        esclerozada
# ..               ...
# 387           zeplu1
# 388         LeoBagno
# 389    kidzwithfrogs
# 390          KuHazza
# 391       kawaharu21
#
# [392 rows x 1 columns]

# %%
u15
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 7000       37000         37000  ...  1122009380315123713      esquerdovky
# 7001       37001         37001  ...            301761876        magaligna
# 7002       37002         37002  ...  1107694982067044352  brigadeiroalfa1
# 7003       37003         37003  ...           3027425951  _rodrigocosta37
# 7004       37004         37004  ...             36944847       eduardovet
# ...          ...           ...  ...                  ...              ...
# 7495       37495         37495  ...  1167592540641681410    kidzwithfrogs
# 7496       37496         37496  ...           3018989687          kuhazza
# 7497       37497         37497  ...  1165403984380735488     lucastzolkin
# 7498       37498         37498  ...  1255371621243793408       kawaharu21
# 7499       37499         37499  ...            346027365         ernane20
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u16.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_16 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_16
# Out:
#              usuario
# 0          MpPeisino
# 1           paula1be
# 2     RomeoZambrotta
# 3     Dsggomes_David
# 4           shyugbam
# ..               ...
# 393   Conservador_38
# 394  ElaineLencastre
# 395  Welling04449520
# 396       le_araujos
# 397      HerisValmir
#
# [398 rows x 1 columns]

# %%
u16
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 7500       37500         37500  ...  1196814838070202369        mppeisino
# 7501       37501         37501  ...           4596629241         paula1be
# 7502       37502         37502  ...   970698882337378304   romeozambrotta
# 7503       37503         37503  ...           1410336997   dsggomes_david
# 7504       37504         37504  ...            827747684         shyugbam
# ...          ...           ...  ...                  ...              ...
# 7995       37995         37995  ...  1119067136251637760  fatima_jaguar38
# 7996       37996         37996  ...  1256655296606474242  welling04449520
# 7997       37997         37997  ...            198354394       le_araujos
# 7998       37998         37998  ...            893321437      herisvalmir
# 7999       37999         37999  ...             56925003           brrvce
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u17.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_17 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_17
# Out:
#             usuario
# 0      Orlando_Prof
# 1          ocachete
# 2    NicolasTCabral
# 3         prodverns
# 4    MiguelMartins1
# ..              ...
# 376     elt0nalonso
# 377     grolimacrvg
# 378       euvidotto
# 379       elishowbb
# 380       danielvm_
#
# [381 rows x 1 columns]

# %%
u17
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 8000       38000         38000  ...  1090807047237570562   christina38jb_
# 8001       38001         38001  ...            390737660     orlando_prof
# 8002       38002         38002  ...             56566775         ocachete
# 8003       38003         38003  ...             62407455   nicolastcabral
# 8004       38004         38004  ...  1248278927552000007        prodverns
# ...          ...           ...  ...                  ...              ...
# 8495       38495         38495  ...  1241712733017571328  rafaelc51829696
# 8496       38496         38496  ...            555654532       itsjohn24_
# 8497       38497         38497  ...           2977352290        euvidotto
# 8498       38498         38498  ...  1213139943402303488        elishowbb
# 8499       38499         38499  ...             28551698        danielvm_
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u18.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_18 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_18
# Out:
#              usuario
# 0        LuzMeireles
# 1             Vissqx
# 2          fchagas04
# 3            amarlua
# 4        Bana_Chipps
# ..               ...
# 393     emery_felipe
# 394  rodrigu08697963
# 395       Lucasnog01
# 396           NecaVo
# 397        tchinieze
#
# [398 rows x 1 columns]

# %%
u18
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 8500       38500         38500  ...  1239021121921527808       acefour9v2
# 8501       38501         38501  ...           1123691461      luzmeireles
# 8502       38502         38502  ...           1325970805           vissqx
# 8503       38503         38503  ...           1459551379        fchagas04
# 8504       38504         38504  ...             17083012          amarlua
# ...          ...           ...  ...                  ...              ...
# 8995       38995         38995  ...   713118668763308032     emery_felipe
# 8996       38996         38996  ...  1115456620530741248  rodrigu08697963
# 8997       38997         38997  ...            402762631       lucasnog01
# 8998       38998         38998  ...  1154990883219156993           necavo
# 8999       38999         38999  ...            477657559        tchinieze
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u19.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_19 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_19
# Out:
#              usuario
# 0      kiki_azzevedo
# 1       Irma56876823
# 2        dondacamara
# 3          rivelania
# 4      josesantana77
# ..               ...
# 413    Mariojstrader
# 414         larieee_
# 415  josecelsoguerra
# 416   pablolgiuliano
# 417     josa_junior_
#
# [418 rows x 1 columns]

# %%
u19
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 9000       39000         39000  ...   717194384840790016    kiki_azzevedo
# 9001       39001         39001  ...  1052697423938768896        mvp_sales
# 9002       39002         39002  ...  1114393499225460736     irma56876823
# 9003       39003         39003  ...             63804808      taniarodini
# 9004       39004         39004  ...           2661716661      dondacamara
# ...          ...           ...  ...                  ...              ...
# 9495       39495         39495  ...  1165019951738105856    mariojstrader
# 9496       39496         39496  ...            144567861         larieee_
# 9497       39497         39497  ...            411007677  josecelsoguerra
# 9498       39498         39498  ...            194354793   pablolgiuliano
# 9499       39499         39499  ...           4119601527     josa_junior_
#
# [500 rows x 5 columns]

# %%
data = []   #para criar o df com as respostas

for x in u20.username:
  try:   
    user = api.get_user(f'{x}')
    usuario = user.screen_name #Selecioanndo o usuario
    data.append((usuario))

  except: #Ignorando erros
      pass

cols=['usuario'] #Criando o df com as respostas
usuarios1_20 = pd.DataFrame(data, columns=cols)

# %%
usuarios1_20
# Out:
#              usuario
# 0        EduardoOlmo
# 1    PetistaAmargur1
# 2        ativosocial
# 3         rodfortuna
# 4       FredBarros72
# ..               ...
# 373    carunchovelho
# 374     Lily_Brujita
# 375  RogrioF48596947
# 376        CarlReis4
# 377     matheus_cf97
#
# [378 rows x 1 columns]

# %%
u20
# Out:
#       Unnamed: 0  Unnamed: 0.1  ...              user_id         username
# 9500       39500         39500  ...  1081629955270852608      eduardoolmo
# 9501       39501         39501  ...  1156334643819552769  petistaamargur1
# 9502       39502         39502  ...  1243497204758843394      ativosocial
# 9503       39503         39503  ...            482399823        gusseabra
# 9504       39504         39504  ...            196701638       rodfortuna
# ...          ...           ...  ...                  ...              ...
# 9995       39995         39995  ...  1207005033499365381     lily_brujita
# 9996       39996         39996  ...  1255747777285554178  rogriof48596947
# 9997       39997         39997  ...  1001945827051495426        carlreis4
# 9998       39998         39998  ...  1057795906861457409     matheus_cf97
# 9999       39999         39999  ...  1213281559920271362  jonatas16575840
#
# [500 rows x 5 columns]

# %%
metade = pd.read_csv('/content/metade_usuarios1')

# %%
metade = [usuarios1_10, usuarios1_11, usuarios1_12, usuarios1_13, usuarios1_14, usuarios1_15, usuarios1_16, usuarios1_17, usuarios1_18, usuarios1_19, usuarios1_20]

# %%
metade_ = pd.concat(metade)

# %%
metade_
# Out:
#              usuario
# 0     matheusbbgodoy
# 1     Anamfranceschi
# 2          blangeani
# 3     pibervaldecir1
# 4       mikka_sansil
# ..               ...
# 373    carunchovelho
# 374     Lily_Brujita
# 375  RogrioF48596947
# 376        CarlReis4
# 377     matheus_cf97
#
# [4335 rows x 1 columns]

# %%
metade_.to_csv('metade_4')
